# %% [markdown]
#  Analysis of source data

# %%
# !which spark-submit
# !echo $SPARK_HOME
# Out:
# /opt/spark

# %%
import findspark
findspark.init()
import pyspark
print(pyspark.__version__)
# Out:
# 2.4.5

# %%
import os
os.environ['SPARK_HOME'] = '/opt/spark'
os.environ['PYSPARK_PYTHON'] = 'python3'
import findspark
findspark.init()
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Test") \
    .master("spark://master:7077") \
    .getOrCreate()

print("✅ PySpark Connected!")
# Out:
# ✅ PySpark Connected!

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from datetime import datetime

# %%
spark = SparkSession.builder\
        .appName("Newyork_jobs_analysis")\
        .getOrCreate()
df = spark.read.csv("/dataset/nyc-jobs.csv",header=True,inferSchema=True)
df.printSchema()
df.show(5)
df.describe()
# Out:
# root
#  |-- Job ID: integer (nullable = true)
#  |-- Agency: string (nullable = true)
#  |-- Posting Type: string (nullable = true)
#  |-- # Of Positions: integer (nullable = true)
#  |-- Business Title: string (nullable = true)
#  |-- Civil Service Title: string (nullable = true)
#  |-- Title Code No: string (nullable = true)
#  |-- Level: string (nullable = true)
#  |-- Job Category: string (nullable = true)
#  |-- Full-Time/Part-Time indicator: string (nullable = true)
#  |-- Salary Range From: double (nullable = true)
#  |-- Salary Range To: double (nullable = true)
#  |-- Salary Frequency: string (nullable = true)
#  |-- Work Location: string (nullable = true)
#  |-- Division/Work Unit: string (nullable = true)
#  |-- Job Description: string (nullable = true)
#  |-- Minimum Qual Requirements: string (nullable = true)
#  |-- Preferred Skills: string (nullable = true)
#  |-- Additional Information: string (nullable = true)
#  |-- To Apply: string (nullable = true)
#  |-- Hours/Shift: string (nullable = true)
#  |-- Work Location 1: string (nullable = true)
#  |-- Recruitment Contact: string (nullable = true)
#  |-- Residency Requirement: string (nullable = true)
#  |-- Posting Date: string (nullable = true)
#  |-- Post Until: string (nullable = true)
#  |-- Posting Updated: string (nullable = true)
#  |-- Process Date: string (nullable = true)
#
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+
# |Job ID|              Agency|Posting Type|# Of Positions|      Business Title| Civil Service Title|Title Code No|Level|        Job Category|Full-Time/Part-Time indicator|Salary Range From|Salary Range To|Salary Frequency|       Work Location|  Division/Work Unit|     Job Description|Minimum Qual Requirements|    Preferred Skills|Additional Information|            To Apply|         Hours/Shift|     Work Location 1| Recruitment Contact|Residency Requirement|        Posting Date|          Post Until|     Posting Updated|        Process Date|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+
# | 87990|DEPARTMENT OF BUS...|    Internal|             1|     Account Manager|CONTRACT REVIEWER...|        40563|    1|                null|                         null|          42405.0|        65485.0|          Annual| 110 William St. N Y|Strategy & Analytics|Division of Econo...|     "1.	A baccalaurea...| all candidates m...|  â€¢	Excellent int...|Salary range for ...|                null|                null|                null|                 null|New York City res...|2011-06-24T00:00:...|                null|2011-06-24T00:00:...|
# | 97899|DEPARTMENT OF BUS...|    Internal|             1|EXECUTIVE DIRECTO...|ADMINISTRATIVE BU...|        10009|   M3|                null|                            F|          60740.0|       162014.0|          Annual| 110 William St. N Y|Tech Talent Pipeline|The New York City...|     "1. A baccalaurea...|                null|                  null|In addition to ap...|                null|                null|                null| New York City res...|2012-01-26T00:00:...|                null|2012-01-26T00:00:...|2019-12-17T00:00:...|
# |132292|NYC HOUSING AUTHO...|    External|            52|Maintenance Worke...|  MAINTENANCE WORKER|        90698|    0|Maintenance & Ope...|                            F|         51907.68|       54580.32|          Annual|Heating Mgt-Opera...|Management Servic...|Under direct supe...|     "1. Three years o...|          mechanical|   or construction ...| may be substitut...| all candidates m...|1.  A High School...|1.  A Motor Vehic...| "Click the ""Appl...|                null|                null|                null|NYCHA has no resi...|
# |132292|NYC HOUSING AUTHO...|    Internal|            52|Maintenance Worke...|  MAINTENANCE WORKER|        90698|    0|Maintenance & Ope...|                            F|         51907.68|       54580.32|          Annual|Heating Mgt-Opera...|Management Servic...|Under direct supe...|     "1. Three years o...|          mechanical|   or construction ...| may be substitut...| all candidates m...|1.  A High School...|1.  A Motor Vehic...| "Click the ""Appl...|                null|                null|                null|NYCHA has no resi...|
# |133921|NYC HOUSING AUTHO...|    Internal|            50|   Temporary Painter|             PAINTER|        91830|    0|Maintenance & Ope...|                            F|             35.0|           35.0|          Hourly|DMP-Contract & An...|Dept of Managemen...|Responsibilities ...|     1. Five years of ...|                null|  SPECIAL NOTE:    ...|"Click the ""Appl...|                null|                null|                null| NYCHA has no resi...|2014-01-09T00:00:...|                null|2014-01-08T00:00:...|2019-12-17T00:00:...|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows
# DataFrame[summary: string, Job ID: string, Agency: string, Posting Type: string, # Of Positions: string, Business Title: string, Civil Service Title: string, Title Code No: string, Level: string, Job Category: string, Full-Time/Part-Time indicator: string, Salary Range From: string, Salary Range To: string, Salary Frequency: string, Work Location: string, Division/Work Unit: string, Job Description: string, Minimum Qual Requirements: string, Preferred Skills: string, Additional Information: string, To Apply: string, Hours/Shift: string, Work Location 1: string, Recruitment Contact: string, Residency Requirement: string, Posting Date: string, Post Until: string, Posting Updated: string, Process Date: string]

# %% [markdown]
# DATA CLEANING FUNCTIONS

# %%
def clean_columns(df):
    for col_name in df.columns:
        df = df.withColumnRenamed(col_name,col_name.lower().replace(" ","_" ))
    return df

df = clean_columns(df)
df.show()
# Out:
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+
# |job_id|              agency|posting_type|#_of_positions|      business_title| civil_service_title|title_code_no|level|        job_category|full-time/part-time_indicator|salary_range_from|salary_range_to|salary_frequency|       work_location|  division/work_unit|     job_description|minimum_qual_requirements|    preferred_skills|additional_information|            to_apply|         hours/shift|     work_location_1| recruitment_contact|residency_requirement
DEPT OF HEALTH/ME...|    Internal|             1|Clerical Associat...|  CLERICAL ASSOCIATE|        10251|    3|Clerical & Admini...|                            F|          32086.0|        51981.0|          Annual|   42-09 28th Street|Communicable Dise...|** OPEN TO PERMAN...|     Qualification Req...|-	Good writing an...|                  null|Apply online with...|                null|42-09 28th Street...|                null| New York City res...|2014-10-08T00:00:...|                null|2014-10-08T00:00:...|2019-12-17T00:00:...|
# |171944|DEPT OF INFO TECH...|    Internal|             1|Deputy Director, ...|COMPUTER ASSOC (T...|        13611|    1|Finance, Accounti...|                         null|          43292.0|        53000.0|          Annual|75 Park Place New...|  Financial Services|DoITT provides fo...|     "Qualification Re...| acquired with th...|   as described in ...|               ""2""| or ""3"" above. ...| from an accredit...| for six months o...|  all candidates m...|  mid-range computer| and/or LAN or WA...| acquired within ...| in the areas of ...|
# |172053|DEPT OF INFO TECH...|    Internal|             1|311 Call Center M...|ADM MANAGER-NON-M...|        1002C|    0|Community & Busin...|                            F|          49492.0|        69000.0|          Annual|      59 Maiden Lane|      311 Operations|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|            managerial| executive or sup...| full-time progre...| 18 months of whi...|          managerial|   executive or su...| ""2"" or ""3"" a...| all  candidates ...|          managerial| executive or sup...|
# |175362|DEPT OF HEALTH/ME...|    Internal|             1|Clerical Associat...|  CLERICAL ASSOCIATE|        10251|    3|Clerical & Admini...|                            F|          32086.0|        51981.0|          Annual|125 Worth Street,...|Vital Statistics/...|**OPEN TO PERMANE...|     Qualification Req...|Experience with c...|                  null|Apply online with...|                null|125 Worth Street,...|                null| New York City res...|2014-11-18T00:00:...|                null|2014-11-18T00:00:...|2019-12-17T00:00:...|
# |177048|DEPT OF INFO TECH...|    Internal|             1|Application Suppo...|COMPUTER SPECIALI...|        13632|    3|Information Techn...|                         null|          81290.0|        95896.0|          Annual|        2 Metro Tech|Develop & Integra...|DoITT provides fo...|     "(1) A baccalaure...| including one ye...|   all candidates m...| plus at least on...| you must explain...|   technical support| quality assuranc...|  hardware install...|           help desk| or as an end use...| in addition to t...| individuals must...|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# PROCESSING DATE FUNCTION:

# %%
def process_dates(df):
    df = df.withColumn("posting_date", to_date(col("posting_date"), "MM/dd/yyyy"))
    df = df.withColumn("year", year(col("posting_date")))
    df = df.withColumn("month", month(col("posting_date")))
    return df

df = process_dates(df)
df.show(5)
# Out:
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+------------+--------------------+--------------------+--------------------+----+-----+
# |job_id|              agency|posting_type|#_of_positions|      business_title| civil_service_title|title_code_no|level|        job_category|full-time/part-time_indicator|salary_range_from|salary_range_to|salary_frequency|       work_location|  division/work_unit|     job_description|minimum_qual_requirements|    preferred_skills|additional_information|            to_apply|         hours/shift|     work_location_1| recruitment_contact|residency_requirement|posting_date|          post_until|     posting_updated|        process_date|year|month|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+------------+--------------------+--------------------+--------------------+----+-----+
# | 87990|DEPARTMENT OF BUS...|    Internal|             1|     Account Manager|CONTRACT REVIEWER...|        40563|    1|                null|                         null|          42405.0|        65485.0|          Annual| 110 William St. N Y|Strategy & Analytics|Division of Econo...|     "1.	A baccalaurea...| all candidates m...|  â€¢	Excellent int...|Salary range for ...|                null|                null|                null|                 null|        null|2011-06-24T00:00:...|                null|2011-06-24T00:00:...|null| null|
# | 97899|DEPARTMENT OF BUS...|    Internal|             1|EXECUTIVE DIRECTO...|ADMINISTRATIVE BU...|        10009|   M3|                null|                            F|          60740.0|       162014.0|          Annual| 110 William St. N Y|Tech Talent Pipeline|The New York City...|     "1. A baccalaurea...|                null|                  null|In addition to ap...|                null|                null|                null| New York City res...|        null|                null|2012-01-26T00:00:...|2019-12-17T00:00:...|null| null|
# |132292|NYC HOUSING AUTHO...|    External|            52|Maintenance Worke...|  MAINTENANCE WORKER|        90698|    0|Maintenance & Ope...|                            F|         51907.68|       54580.32|          Annual|Heating Mgt-Opera...|Management Servic...|Under direct supe...|     "1. Three years o...|          mechanical|   or construction ...| may be substitut...| all candidates m...|1.  A High School...|1.  A Motor Vehic...| "Click the ""Appl...|        null|                null|                null|NYCHA has no resi...|null| null|
# |132292|NYC HOUSING AUTHO...|    Internal|            52|Maintenance Worke...|  MAINTENANCE WORKER|        90698|    0|Maintenance & Ope...|                            F|         51907.68|       54580.32|          Annual|Heating Mgt-Opera...|Management Servic...|Under direct supe...|     "1. Three years o...|          mechanical|   or construction ...| may be substitut...| all candidates m...|1.  A High School...|1.  A Motor Vehic...| "Click the ""Appl...|        null|                null|                null|NYCHA has no resi...|null| null|
# |133921|NYC HOUSING AUTHO...|    Internal|            50|   Temporary Painter|             PAINTER|        91830|    0|Maintenance & Ope...|                            F|             35.0|           35.0|          Hourly|DMP-Contract & An...|Dept of Managemen...|Responsibilities ...|     1. Five years of ...|                null|  SPECIAL NOTE:    ...|"Click the ""Appl...|                null|                null|                null| NYCHA has no resi...|        null|                null|2014-01-08T00:00:...|2019-12-17T00:00:...|null| null|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+------------+--------------------+--------------------+--------------------+----+-----+
# only showing top 5 rows

# %% [markdown]
# Average salary calculation

# %%
def process_salary(df):
    """
    Compute avg_salary = (salary_range_from + salary_range_to) / 2
    and return the values as a dataframe
    """
    df = df.withColumn(
        "avg_salary",
        (col("salary_range_from") + col("salary_range_to")) / 2
    )
    return df

df = process_salary(df)
df.show()
# Out:
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+------------+--------------------+--------------------+--------------------+----+-----+----------+
# |job_id|              agency|posting_type|#_of_positions|      business_title| civil_service_title|title_code_no|level|        job_category|full-time/part-time_indicator|salary_range_from|salary_range_to|salary_frequency|       work_location|  division/work_unit|     job_description|minimum_qual_requirements|    preferred_skills|additional_information|            to_apply|         hours/shift|     work_location_1| recruitment_contact|residency_requirement|posting_date|          post_until|     posting_updated|        process_date|year|month|avg_salary|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+------------+--------------------+--------------------+--------------------+----+-----+----------+
# | 87990|DEPARTMENT OF BUS...|    Internal|             1|     Account Manager|CONTRACT REVIEWER...|        40563|    1|                null|                         null|          42405.0|        65485.0|          Annual| 110 William St. N Y|Strategy & Analytics|Division of Econo...|     "1
             1|COLLEGE AIDE - CL...|COLLEGE AIDE (ALL...|        10209|    1|Clerical & Admini...|                            P|             8.75|          10.36|          Hourly|     100 Gold Street|      Administration|The Office of Col...|     For Assignment Le...|1.	Excellent inte...|                  null|Click the â€œAppl...|Hours:  17 hours ...|                null|                null| New York City res...|        null|                null|2014-10-16T00:00:...|2019-12-17T00:00:...|null| null|     9.555|
# |170989|OFFICE OF COLLECT...|    External|             1|COLLEGE AIDE - CL...|COLLEGE AIDE (ALL...|        10209|    1|Clerical & Admini...|                            P|             8.75|          10.36|          Hourly|     100 Gold Street|      Administration|The Office of Col...|     For Assignment Le...|1.	Excellent inte...|                  null|Click the â€œAppl...|Hours:  17 hours ...|                null|                null| New York City res...|        null|                null|2014-10-16T00:00:...|2019-12-17T00:00:...|null| null|     9.555|
# |171040|DEPT OF HEALTH/ME...|    Internal|             1|Clerical Associat...|  CLERICAL ASSOCIATE|        10251|    3|Clerical & Admini...|                            F|          32086.0|        51981.0|          Annual|   42-09 28th Street|Communicable Dise...|** OPEN TO PERMAN...|     Qualification Req...|-	Good writing an...|                  null|Apply online with...|                null|42-09 28th Street...|                null| New York City res...|        null|                null|2014-10-08T00:00:...|2019-12-17T00:00:...|null| null|   42033.5|
# |171944|DEPT OF INFO TECH...|    Internal|             1|Deputy Director, ...|COMPUTER ASSOC (T...|        13611|    1|Finance, Accounti...|                         null|          43292.0|        53000.0|          Annual|75 Park Place New...|  Financial Services|DoITT provides fo...|     "Qualification Re...| acquired with th...|   as described in ...|               ""2""| or ""3"" above. ...| from an accredit...| for six months o...|  all candidates m...|        null| and/or LAN or WA...| acquired within ...| in the areas of ...|null| null|   48146.0|
# |172053|DEPT OF INFO TECH...|    Internal|             1|311 Call Center M...|ADM MANAGER-NON-M...|        1002C|    0|Community & Busin...|                            F|          49492.0|        69000.0|          Annual|      59 Maiden Lane|      311 Operations|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|            managerial| executive or sup...| full-time progre...| 18 months of whi...|          managerial|   executive or su...|        null| all  candidates ...|          managerial| executive or sup...|null| null|   59246.0|
# |175362|DEPT OF HEALTH/ME...|    Internal|             1|Clerical Associat...|  CLERICAL ASSOCIATE|        10251|    3|Clerical & Admini...|                            F|          32086.0|        51981.0|          Annual|125 Worth Street,...|Vital Statistics/...|**OPEN TO PERMANE...|     Qualification Req...|Experience with c...|                  null|Apply online with...|                null|125 Worth Street,...|                null| New York City res...|        null|                null|2014-11-18T00:00:...|2019-12-17T00:00:...|null| null|   42033.5|
# |177048|DEPT OF INFO TECH...|    Internal|             1|Application Suppo...|COMPUTER SPECIALI...|        13632|    3|Information Techn...|                         null|          81290.0|        95896.0|          Annual|        2 Metro Tech|Develop & Integra...|DoITT provides fo...|     "(1) A baccalaure...| including one ye...|   all candidates m...| plus at least on...| you must explain...|   technical support| quality assuranc...|  hardware install...|        null| or as an end use...| in addition to t...| individuals must...|null| null|   88593.0|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+------------+--------------------+--------------------+--------------------+----+-----+----------+
# only showing top 20 rows

# %% [markdown]
# KPI 1  -- NUMBER OF JOBS PER CATEGORY

# %%
top_jobs_category = df.groupBy("job_category")\
                    .count()\
                    .orderBy(desc("count"))\
                    .limit(10)

top_jobs_category.show(5)

# %% [markdown]
# KPI 2 -- SALARY DISTRIBUTION PER JOB CATEGORY

# %%
salary_by_cateogry = df.groupBy("job_categrory")\
                        .agg(avg("avg_salary").alias("avg_salary"))\
                        .orderBy(desc("avg_salary"))
salary_by_cateogry.show(5)

# %% [markdown]
# KPI 3 -- Correlation Between Degree & Salary

# %%
def extract_degree():
    return when(lower(col("minimum_qualifications")).contains("phd"), "PhD") \
        .when(lower(col("minimum_qualifications")).contains("master"), "Masters") \
        .when(lower(col("minimum_qualifications")).contains("bachelor"), "Bachelors") \
        .otherwise("No Degree")

df = df.withColumn("degree_level", extract_degree())

df = df.withColumn(
    "degree_encoded",
    when(col("degree_level") == "PhD", 3)
    .when(col("degree_level") == "Masters", 2)
    .when(col("degree_level") == "Bachelors", 1)
    .otherwise(0)
)

df.stat.corr("degree_encoded", "avg_salary")

# %% [markdown]
# KPI 4 -- job posting having the highest salary per agency

# %%
##from pyspark.sql.functions import window
w = window.partitionBy("Agency").orderBy(desc("avg_salary"))

highest_salary_per_agency = (
    df.withColumn("rank", row_number().over(w))
      .filter(col("rank") == 1)
      .select("agency", "business_title", "avg_salary")
)

highest_salary_per_agency.show(5)

# %% [markdown]
# KPI 5 --  job positings average salary per agency for the last 2 yearS

# %%
two_years_ago = datetime.now().year - 2

df_recent = df.filter(col("year") >= two_years_ago)

avg_salary_last_2_years = (
    df_recent.groupBy("agency")
             .agg(avg("avg_salary").alias("avg_salary"))
             .orderBy(desc("avg_salary"))
)

avg_salary_last_2_years.show()

# %% [markdown]
# KPI 6 -- highest paid skills in the US market

# %%
#for this KPI I understand this can be done with Regex. As data doesnt have 
#skills column we can do it with the help of 2 different columns which is skills preferred and job desciption by exploding the values of it

# %% [markdown]
# FEATURE REMOVAL

# %%
columns_to_drop = [
    "salary_range_from",
    "salary_range_to"
]

df_final = df.drop(*columns_to_drop)

# %% [markdown]
# WRITE TO FINAL TABLE

# %%
df_final.write.mode("overwrite").parquet("nyc_jobs_processed")

# %%
df = spark.read.csv("/dataset/nyc-jobs.csv", header=True)
df.printSchema()
# Out:
# root
#  |-- Job ID: string (nullable = true)
#  |-- Agency: string (nullable = true)
#  |-- Posting Type: string (nullable = true)
#  |-- # Of Positions: string (nullable = true)
#  |-- Business Title: string (nullable = true)
#  |-- Civil Service Title: string (nullable = true)
#  |-- Title Code No: string (nullable = true)
#  |-- Level: string (nullable = true)
#  |-- Job Category: string (nullable = true)
#  |-- Full-Time/Part-Time indicator: string (nullable = true)
#  |-- Salary Range From: string (nullable = true)
#  |-- Salary Range To: string (nullable = true)
#  |-- Salary Frequency: string (nullable = true)
#  |-- Work Location: string (nullable = true)
#  |-- Division/Work Unit: string (nullable = true)
#  |-- Job Description: string (nullable = true)
#  |-- Minimum Qual Requirements: string (nullable = true)
#  |-- Preferred Skills: string (nullable = true)
#  |-- Additional Information: string (nullable = true)
#  |-- To Apply: string (nullable = true)
#  |-- Hours/Shift: string (nullable = true)
#  |-- Work Location 1: string (nullable = true)
#  |-- Recruitment Contact: string (nullable = true)
#  |-- Residency Requirement: string (nullable = true)
#  |-- Posting Date: string (nullable = true)
#  |-- Post Until: string (nullable = true)
#  |-- Posting Updated: string (nullable = true)
#  |-- Process Date: string (nullable = true)

# %% [markdown]
# ### Sample function

# %%
def get_salary_frequency(df: DataFrame) -> list:
    row_list = df.select('Salary Frequency').distinct().collect()
    return [row['Salary Frequency'] for row in row_list]

# %% [markdown]
# ### Example of test function

# %%
mock_data = [('A', 'Annual'), ('B', 'Daily')]
expected_result = ['Annual', 'Daily']

# %%
def test_get_salary_frequency(mock_data: list, 
                              expected_result: list,
                              schema: list = ['id', 'Salary Frequency']):  
    mock_df = spark.createDataFrame(data = mock_data, schema = schema)
    assert get_salary_frequency(mock_df) == expected_result
